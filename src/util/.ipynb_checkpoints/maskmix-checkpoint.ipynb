# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
def imshow(img):
    if img.ndim == 2:
        plt.imshow(img, cmap="gray")
    else:
        plt.imshow(img[..., ::-1])
    plt.axis("off")
    plt.show()

# %%
foreground = cv2.imread("../../data/example/dog.jpg")
background = cv2.imread("../../data/example/lab_table_4_img_000230.png")
foreground = cv2.resize(foreground, (256,256))
background = cv2.resize(background, (256,256))

# %%
#grayscaleに変換する
gray = cv2.cvtColor(foreground, cv2.COLOR_BGR2GRAY)

# 2値化する。
_, binary = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)
imshow(binary)

# %%
# 輪郭抽出する。
contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
# 検出された輪郭内部を255で塗りつぶす。
mask = np.zeros_like(binary)
cv2.drawContours(mask, contours, -1, color=255, thickness=-1)

# 以上の手順で前景画像のうち、合成する画素を255としたマスク画像が作成できた。
imshow(mask)

# %%
bgr = cv2.imread("../../data/example/dog.jpg")
bgr = cv2.cvtColor(bgr, cv2.COLOR_RGB2BGR)
h, w = bgr.shape[:2]
mask = np.zeros((h,w), dtype = np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect=(1,1,w,h)
cv2.grabCut(bgr, mask, rect, bgdModel, fgdModel, 10, cv2.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
bgr2 = bgr*mask2[:,:,np.newaxis]

# %%
plt.imshow(bgr2)

# %%
#grayscaleに変換する
gray = cv2.cvtColor(bgr2, cv2.COLOR_BGR2GRAY)

plt.imshow(gray)

# %%
# 2値化する。
_, binary = cv2.threshold(gray, 50, 255, cv2.THRESH_BINARY_INV)

imshow(binary)

# %%
# 輪郭抽出する。
contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# 検出された輪郭内部を255で塗りつぶす。
mask = np.zeros_like(binary)
cv2.drawContours(mask, contours, -1, color=(255,255,255), thickness=-1)

# 以上の手順で前景画像のうち、合成する画素を255としたマスク画像が作成できた。
imshow(mask)

# %%
h, w = bgr2.shape[:2]  # 前景画像の大きさ
x, y = random.randint(0,256), random.randint(0,256)  # 背景画像の座標上で前景画像を貼り付ける位置
roi = background[y : y + h, x : x + w, :]
result = np.where(np.expand_dims(mask == 255, -1), bgr2, roi)

imshow(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-8d59dd009e2a> in <module>
#       2 x, y = random.randint(0,256), random.randint(0,256)  # 背景画像の座標上で前景画像を貼り付ける位置
#       3 roi = background[y : y + h, x : x + w, :]
# ----> 4 result = np.where(np.expand_dims(mask == 255, -1), bgr2, roi)
#       5
#       6 imshow(result)
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: operands could not be broadcast together with shapes (720,720,1) (720,720,3) (180,252,3)

# %%
h, w = foreground.shape[:2]  # 前景画像の大きさ
x, y = random.randint(0,256), random.randint(0,256)  # 背景画像の座標上で前景画像を貼り付ける位置
roi = background[y : y + h, x : x + w, :]
result = np.where(np.expand_dims(mask == 255, -1), foreground, roi)

imshow(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ee185bcf6279> in <module>
#       2 x, y = random.randint(0,256), random.randint(0,256)  # 背景画像の座標上で前景画像を貼り付ける位置
#       3 roi = background[y : y + h, x : x + w, :]
# ----> 4 result = np.where(np.expand_dims(mask == 255, -1), foreground, roi)
#       5
#       6 imshow(result)
#
# <__array_function__ internals> in where(*args, **kwargs)
#
# ValueError: operands could not be broadcast together with shapes (720,720,1) (256,256,3) (190,66,3)

# %%
np.expanddims(mask==255,-1)
